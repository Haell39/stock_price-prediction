# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# Configuração do estilo
plt.style.use('fivethirtyeight')
# %matplotlib inline

# Gerando dados aleatórios para testar o gráfico
dates = pd.date_range(start='2024-01-01', periods=100, freq='D')
data = np.cumsum(np.random.randn(100))

df = pd.DataFrame({'Date': dates, 'Value': data})

# Criando um gráfico
plt.figure(figsize=(10, 5))
plt.plot(df['Date'], df['Value'], label='Random Data')
plt.xlabel('Data')
plt.ylabel('Valor')
plt.title('Teste Matplotlib Inline')
plt.legend()
plt.show()
